# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyakamatagi/python-moments-of-business/blob/main/basic_data_analysis_(salary).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# loading the dataset

# %%
df=pd.read_csv("Salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
pd.set_option("display.max_rows",None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df["discipline"].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
df["sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
pip install missingno

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# the data is free from null values

# %% [markdown]
# # **PAIRPLOT**
# (TO understand the relation between different variables and missing values)

# %%
sns.pairplot(df)

# %% [markdown]
# # **GROUP BY**

# %%
df.groupby(["sex","discipline","rank"])["salary"].sum()
# Out:
# sex     discipline  rank
# Female  A           AssocProf     288514
#                     AsstProf      437600
#                     Prof          877055
#         B           AssocProf     596614
#                     AsstProf      420949
#                     Prof         1318362
# Male    A           AssocProf      81285
#                     AsstProf      158000
#                     Prof         1697466
#         B           AssocProf     226808
#                     AsstProf      529344
#                     Prof         1793858
# Name: salary, dtype: int64

# %% [markdown]
# # **PIE PLOT**
# (calculating the praportion of rank(prof , assoc prof and assistent prof , gender (male and female) & discipline (A&B)))

# %%
# praporting of assistant professors , professors and associate professors

# %%
rank_count=df["rank"].value_counts()
per=(rank_count/77*100)
per
# Out:
# rank
# Prof         59.740260
# AsstProf     24.675325
# AssocProf    16.883117
# Name: count, dtype: float64

# %%
sex_count=df["sex"].value_counts()
per_1=(sex_count/77*100)
per_1
# Out:
# sex
# Male      50.649351
# Female    50.649351
# Name: count, dtype: float64

# %%
dis_count=df["discipline"].value_counts()
per_2=(dis_count/77*100)
per_2
# Out:
# discipline
# B    54.545455
# A    46.753247
# Name: count, dtype: float64

# %%
plt.subplot(2,2,1)
per.plot(figsize=(10,8),kind="pie")
plt.subplot(2,2,2)
per_1.plot(figsize=(10,8),kind="pie")
plt.plot(2,2,3)
per_2.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **INTERPRETATION**
#
# * the praportion of professors are comparitively more than assistent professor and associate professor
# * while Male  with B Discipline is slightly  more than Female with A discipline

# %% [markdown]
# # **UNIVARIATE ANALYSIS** (analysing salary across different columns)
# salary (professor  vs  assocoate professor  vs  assistent professor )

# %%
# salary vs rank
# which rank employee  is earning more

# %%
sns.set_style(style="darkgrid")
sns.displot(df,x="salary",col="rank",kde=True,hue="rank")
sns.displot(df,x="salary",col="discipline",kde=True,hue="discipline")
sns.displot(df,x="salary",col="sex",kde=True,hue="sex")

# %% [markdown]
# # **INTERPRETATION**
# * from the above visualizations , we can make the following interpretations
# * among the ranks (professor,  associate professor  and assistent professor ) professors are earning comparitively more than any other rank
# * among disciplines , B discipline is earning more than A discipline
# *

# %%
sns.displot(df,x="salary",hue="sex",kind="kde")
plt.figure(figsize=(10,8))
sns.displot(df,x="salary",hue="rank",kind="kde")
sns.displot(df,x="salary",hue="discipline",kind="kde")

# %% [markdown]
# # **PHD**
# (professor vs associate professor vs assistent professor )

# %%
sns.set_style(style="darkgrid")
sns.displot(df,x="phd",col="rank",kde=True,hue="rank")
sns.displot(df,x="phd",col="sex",kde=True,hue="sex")
sns.displot(df,x="phd",col="discipline",kde=True,hue="discipline")

# %% [markdown]
# # **SERVICE**

# %%
sns.displot(df,x="service",hue="rank",kind="kde",fill=True)
sns.displot(df,x="service",hue="sex",kind="kde",fill=True)
sns.displot(df,x="service",hue="discipline",kind="kde",fill=True)
