# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyakamatagi/python-moments-of-business/blob/main/basic_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import all libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset

# %%
data=pd.read_csv('Salaries.csv')
data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
data.shape
# Out:
# (78, 6)

# %%
pd.set_option('display.max_rows',None)
data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# setting the column as index

# %%
df=data.set_index(['rank','sex'])
df
# Out:
#                  discipline  phd  service  salary
# rank      sex
# Prof      Male            B   56       49  186960
#           Male            A   12        6   93000
#           Male            A   23       20  110515
#           Male            A   40       31  131205
#           Male            B   20       18  104800
#           Male            A   20       20  122400
# AssocProf Male            A   20       17   81285
# Prof      Male            A   18       18  126300
#           Male            A   29       19   94350
#           Male            A   51       51   57800
#           Male            B   39       33  128250
#           Male            B   23       23  134778
# AsstProf  Male            B    1        0   88000
# Prof      Male            B   35       33  162200
#           Male            B   25       19  153750
#           Male            B   17        3  150480
# AsstProf  Male            B    8        3   75044
# ...

# %%
# sorting the index

# %%
df.sort_index(ascending=True)
# Out:
#                  discipline  phd  service  salary
# rank      sex
# AssocProf Female          A   13        8   74830
#           Female          B   11       11  103613
#           Female          A   25       22   62884
#           Female          A   10        8   77500
#           Female          B   12       10  103994
#           Female          B   13       10  103750
#           Female          B   14        7  109650
#           Female          A   26       24   73300
#           Female          B   12        9   71065
#           Female          B   19        6  104542
#           Male            A   20       17   81285
#           Male            B    9        7  107008
#           Male            B   12        8  119800
# AsstProf  Female          B    4        2   80225
#           Female          B    5        0   77000
#           Female          B   11        3   74692
#           Female          B   10        5   97032
# ...

# %%
af=df.loc['AssocProf']
af
# Out:
#        discipline  phd  service  salary
# sex
# Male            A   20       17   81285
# Male            B    9        7  107008
# Male            B   12        8  119800
# Female          A   13        8   74830
# Female          B   11       11  103613
# Female          A   25       22   62884
# Female          A   10        8   77500
# Female          B   12       10  103994
# Female          B   13       10  103750
# Female          B   14        7  109650
# Female          A   26       24   73300
# Female          B   12        9   71065
# Female          B   19        6  104542

# %%
af.shape
# Out:
# (13, 4)

# %%
ap=df.loc['AsstProf']
ap
# Out:
#        discipline  phd  service  salary
# sex
# Male            B    1        0   88000
# Male            B    8        3   75044
# Male            B    4        0   92000
# Male            B    4        4   92000
# Male            A    4        2   73000
# Male            A    2        0   85000
# Male            B    7        2   91300
# Male            B    4        3   91000
# Female          B    4        2   80225
# Female          B    5        0   77000
# Female          B   11        3   74692
# Female          B   10        5   97032
# Female          A    5        3   73500
# Female          A    2        0   72500
# Female          A    3        1   72500
# Female          B    3        3   92000
# Female          A    7        6   63100
# Female          A    4        2   77500
# Female          A    8        3   78500

# %%
ap.shape
# Out:
# (19, 4)

# %%
pr=df.loc['Prof']
pr
# Out:
#        discipline  phd  service  salary
# sex
# Male            B   56       49  186960
# Male            A   12        6   93000
# Male            A   23       20  110515
# Male            A   40       31  131205
# Male            B   20       18  104800
# Male            A   20       20  122400
# Male            A   18       18  126300
# Male            A   29       19   94350
# Male            A   51       51   57800
# Male            B   39       33  128250
# Male            B   23       23  134778
# Male            B   35       33  162200
# Male            B   25       19  153750
# Male            B   17        3  150480
# Male            A   19        7  107300
# Male            A   29       27  150500
# Male            A   33       30  103106
# Male            A   30       23   91100
# Male            B   35       31   99418
# Male            A   38       19  148750
# Male            A   45       43  155865
# Male            B   21       20  123683
# ...

# %%
pr.shape
# Out:
# (46, 4)

# %%
# from the dataset we can understand that there are more number of professors compared to assistent professors and associate profesors

# %%
df1=data.set_index(['sex','rank'])
df1
# Out:
#                  discipline  phd  service  salary
# sex    rank
# Male   Prof               B   56       49  186960
#        Prof               A   12        6   93000
#        Prof               A   23       20  110515
#        Prof               A   40       31  131205
#        Prof               B   20       18  104800
#        Prof               A   20       20  122400
#        AssocProf          A   20       17   81285
#        Prof               A   18       18  126300
#        Prof               A   29       19   94350
#        Prof               A   51       51   57800
#        Prof               B   39       33  128250
#        Prof               B   23       23  134778
#        AsstProf           B    1        0   88000
#        Prof               B   35       33  162200
#        Prof               B   25       19  153750
#        Prof               B   17        3  150480
#        AsstProf           B    8        3   75044
# ...

# %%
df1.loc['Male'] # male employees
# Out:
#           discipline  phd  service  salary
# rank
# Prof               B   56       49  186960
# Prof               A   12        6   93000
# Prof               A   23       20  110515
# Prof               A   40       31  131205
# Prof               B   20       18  104800
# Prof               A   20       20  122400
# AssocProf          A   20       17   81285
# Prof               A   18       18  126300
# Prof               A   29       19   94350
# Prof               A   51       51   57800
# Prof               B   39       33  128250
# Prof               B   23       23  134778
# AsstProf           B    1        0   88000
# Prof               B   35       33  162200
# Prof               B   25       19  153750
# Prof               B   17        3  150480
# AsstProf           B    8        3   75044
# AsstProf           B    4        0   92000
# Prof               A   19        7  107300
# Prof               A   29       27  150500
# AsstProf           B    4        4   92000
# ...

# %%
male=df1.loc['Male']
male.shape
# Out:
# (39, 4)

# %%
female=df1.loc['Female']
female
# Out:
#           discipline  phd  service  salary
# rank
# Prof               B   18       18  129000
# Prof               A   39       36  137000
# AssocProf          A   13        8   74830
# AsstProf           B    4        2   80225
# AsstProf           B    5        0   77000
# Prof               B   23       19  151768
# Prof               B   25       25  140096
# AsstProf           B   11        3   74692
# AssocProf          B   11       11  103613
# Prof               B   17       17  111512
# Prof               B   17       18  122960
# AsstProf           B   10        5   97032
# Prof               B   20       14  127512
# Prof               A   12        0  105000
# AsstProf           A    5        3   73500
# AssocProf          A   25       22   62884
# AsstProf           A    2        0   72500
# AssocProf          A   10        8   77500
# AsstProf           A    3        1   72500
# Prof               B   36       26  144651
# AssocProf          B   12       10  103994
# ...

# %%
female.shape
# Out:
# (39, 4)

# %%
# no of male=no of female

# %%
# groupby

# %%
df.groupby(['rank','sex']).agg({'salary':['mean','min','max','sum']})
# Out:
#                          salary
#                            mean    min     max      sum
# rank      sex
# AssocProf Female   88512.800000  62884  109650   885128
#           Male    102697.666667  81285  119800   308093
# AsstProf  Female   78049.909091  63100   97032   858549
#           Male     85918.000000  73000   92000   687344
# Prof      Female  121967.611111  90450  161101  2195417
#           Male    124690.142857  57800  186960  3491324

# %%
# graphical techniques

# %%
# checking for null values

# %%
sns.heatmap(df.isnull(),cbar=True)
# Out:
# <Axes: ylabel='rank-sex'>

# %%
# the data is free from null values

# %%
# boxplots

# %%
sns.boxplot(x='salary',y='sex',data=data)
# Out:
# <Axes: xlabel='salary', ylabel='sex'>

# %%
# understanding the relation using scatterplot

# %%
figure=plt.figure(figsize=(9,5))
sns.scatterplot(x='phd',y='salary',data=df,color='green')
# Out:
# <Axes: xlabel='phd', ylabel='salary'>

# %%
# positive linear association

# %%
figure=plt.figure(figsize=(9,5))
sns.scatterplot(x='service',y='salary',data=df,color='black')
# Out:
# <Axes: xlabel='service', ylabel='salary'>

# %%
# as the no of yeras served increases , salary also increases

# %%
figure=plt.figure(figsize=(9,5))
sns.histplot(x='rank',y='salary',data=df,color='red')
# Out:
# <Axes: xlabel='rank', ylabel='salary'>

# %%
# the employee with professor rank is receiving highest salary (>1,80,000)
# while the employee with assistent professor is receiving the lowest salary(>1,00,000)

# %%
# comparing the salaries among different disciplines

# %%
sns.barplot(x='discipline',y='salary',data=df,hue='discipline')
# Out:
# <Axes: xlabel='discipline', ylabel='salary'>

# %%
# compared to 'A'discipline, 'B' discipline is receiving more salary(>1,00,000)

# %%
# comparing the salaries of genders

# %%
sns.barplot(x='sex',y='salary',data=df,hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
# male is getting the higher salary compared to female
