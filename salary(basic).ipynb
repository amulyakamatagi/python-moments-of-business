# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyakamatagi/python-moments-of-business/blob/main/salary(basic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset

# %%
df=pd.read_csv('Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
figure=plt.figure(figsize=(8,8))
df.plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# displaying the entire dataset

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
# indexing

# %%
data=df.set_index(['sex','rank'])

# %%
data
# Out:
#                  discipline  phd  service  salary
# sex    rank
# Male   Prof               B   56       49  186960
#        Prof               A   12        6   93000
#        Prof               A   23       20  110515
#        Prof               A   40       31  131205
#        Prof               B   20       18  104800
#        Prof               A   20       20  122400
#        AssocProf          A   20       17   81285
#        Prof               A   18       18  126300
#        Prof               A   29       19   94350
#        Prof               A   51       51   57800
#        Prof               B   39       33  128250
#        Prof               B   23       23  134778
#        AsstProf           B    1        0   88000
#        Prof               B   35       33  162200
#        Prof               B   25       19  153750
#        Prof               B   17        3  150480
#        AsstProf           B    8        3   75044
# ...

# %%
data.loc['Male']
# Out:
#           discipline  phd  service  salary
# rank
# Prof               B   56       49  186960
# Prof               A   12        6   93000
# Prof               A   23       20  110515
# Prof               A   40       31  131205
# Prof               B   20       18  104800
# Prof               A   20       20  122400
# AssocProf          A   20       17   81285
# Prof               A   18       18  126300
# Prof               A   29       19   94350
# Prof               A   51       51   57800
# Prof               B   39       33  128250
# Prof               B   23       23  134778
# AsstProf           B    1        0   88000
# Prof               B   35       33  162200
# Prof               B   25       19  153750
# Prof               B   17        3  150480
# AsstProf           B    8        3   75044
# AsstProf           B    4        0   92000
# Prof               A   19        7  107300
# Prof               A   29       27  150500
# AsstProf           B    4        4   92000
# ...

# %%
data.loc['Female']
# Out:
#           discipline  phd  service  salary
# rank
# Prof               B   18       18  129000
# Prof               A   39       36  137000
# AssocProf          A   13        8   74830
# AsstProf           B    4        2   80225
# AsstProf           B    5        0   77000
# Prof               B   23       19  151768
# Prof               B   25       25  140096
# AsstProf           B   11        3   74692
# AssocProf          B   11       11  103613
# Prof               B   17       17  111512
# Prof               B   17       18  122960
# AsstProf           B   10        5   97032
# Prof               B   20       14  127512
# Prof               A   12        0  105000
# AsstProf           A    5        3   73500
# AssocProf          A   25       22   62884
# AsstProf           A    2        0   72500
# AssocProf          A   10        8   77500
# AsstProf           A    3        1   72500
# Prof               B   36       26  144651
# AssocProf          B   12       10  103994
# ...

# %%
# visualizing

# %%
sns.set_style(style='whitegrid')
figure=plt.figure(figsize=(8,8))
sns.histplot(x='sex',y='salary',hue='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %% [markdown]
# From the above plot, we can understand that Male  are comparitively earning higher(>1,80,000) than that of Female
# (>1,60,000)

# %%
sns.set_style(style='whitegrid')
figure=plt.figure(figsize=(8,8))
sns.barplot(x='rank',y='salary',data=df,hue='rank')
# Out:
# <Axes: xlabel='rank', ylabel='salary'>

# %% [markdown]
# # **INFERENCE:**
# from the above visualization , we can comprehend ranks who are receiving higher salary
# * among all the ranks , the salary of an Assistent professor is low while a professor's salary is higher
# * while an associate professor's salary is  comparitively lower than an profreesor and higher than Assistant professor

# %%
sns.set_style(style='whitegrid')
figure=plt.figure(figsize=(8,8))
sns.lineplot(x='rank',y='salary',data=df)
# Out:
# <Axes: xlabel='rank', ylabel='salary'>

# %%
sns.set_style(style='whitegrid')
figure=plt.figure(figsize=(8,8))
sns.lineplot(x='sex',y='salary',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
# comparitively , Male is getting high paid compared to female

# %%
# groupby

# %%
data.groupby(['rank','sex']).agg({'salary':['mean','max','min']})
# Out:
#                          salary
#                            mean     max    min
# rank      sex
# AssocProf Female   88512.800000  109650  62884
#           Male    102697.666667  119800  81285
# AsstProf  Female   78049.909091   97032  63100
#           Male     85918.000000   92000  73000
# Prof      Female  121967.611111  161101  90450
#           Male    124690.142857  186960  57800

# %% [markdown]
# # **INFERENCE:**
#
# * through the above function , we can analyse the mean salary of different ranks and gender

# %%
# checking for null values

# %%
data.isnull().sum()
# Out:
# discipline    0
# phd           0
# service       0
# salary        0
# dtype: int64

# %%
# graphical representation

# %%
sns.heatmap(data.isnull(),cbar=True)
# Out:
# <Axes: ylabel='sex-rank'>

# %%
# the data is free from all the dataset

# %%
# correlation

# %%
figure=plt.figure(figsize=(9,9))
heatmap=sns.heatmap(data.corr(),cmap='Blues',vmin=-1,vmax=1,annot=True)
heatmap.set_title('correlation_heatmap')
# Out:
# <ipython-input-30-2191ca604af1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap=sns.heatmap(data.corr(),cmap='Blues',vmin=-1,vmax=1,annot=True)
# Text(0.5, 1.0, 'correlation_heatmap')

# %%
# scatterplot

# %%
sns.scatterplot(x='service',y='salary',data=data,color='teal')
plt.title('SCATTERPLOT')
# Out:
# Text(0.5, 1.0, 'SCATTERPLOT')

# %% [markdown]
# from the scatterplot , we can comprehend that the variables are positively linear associated to each other
# as the no of years served increases , the salary also increases

# %%
# as the service increases , salary also increases

# %%
sns.scatterplot(x='phd',y='salary',data=data,color='darkred')
# Out:
# <Axes: xlabel='phd', ylabel='salary'>

# %%
sns.catplot(x='discipline',y='salary',data=data,color='deeppink',jitter=False)

# %% [markdown]
# Employees in displine B are earning more compared to Discipline A

# %%
figure=plt.figure(figsize=(9,9))
sns.catplot(x='phd',y='sex',data=data,hue='sex',kind='swarm')
